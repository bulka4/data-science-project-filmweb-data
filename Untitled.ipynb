# %%
import pandas as pd

# %%
df=pd.DataFrame([['adbdabadbdabadbdabdabdabdabdabadbadbadb' for i in range(40)],['adbdabadbdabadbdabdabdabdabdabadbadbadb' for i in range(40)]])
df
# Out:
#                                         0   \
# 0  adbdabadbdabadbdabdabdabdabdabadbadbadb
# 1  adbdabadbdabadbdabdabdabdabdabadbadbadb
#
#                                         1   \
# 0  adbdabadbdabadbdabdabdabdabdabadbadbadb
# 1  adbdabadbdabadbdabdabdabdabdabadbadbadb
#
#                                         2   \
# 0  adbdabadbdabadbdabdabdabdabdabadbadbadb
# 1  adbdabadbdabadbdabdabdabdabdabadbadbadb
#
#                                         3   \
# 0  adbdabadbdabadbdabdabdabdabdabadbadbadb
# 1  adbdabadbdabadbdabdabdabdabdabadbadbadb
#
#                                         4   \
# 0  adbdabadbdabadbdabdabdabdabdabadbadbadb
# 1  adbdabadbdabadbdabdabdabdabdabadbadbadb
#
#                                         5   \
# 0  adbdabadbdabadbdabdabdabdabdabadbadbadb
# 1  adbdabadbdabadbdabdabdabdabdabadbadbadb
#
#                                         6   \
# 0  adbdabadbdabadbdabdabdabdabdabadbadbadb
# 1  adbdabadbdabadbdabdabdabdabdabadbadbadb
#
# ...

# %%
pd.DataFrame([[1,2],[3,4]])
# Out:
#    0  1
# 0  1  2
# 1  3  4
